# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches"
headers = {"User-Agent": "Mozilla/5.0"}

response = requests.get(url, headers=headers)

print("Status code:", response.status_code)

soup = BeautifulSoup(response.text, "html.parser")

tables = soup.find_all("table", {"class": "wikitable"})

print("Tablas encontradas:", len(tables))

# Extraer filas manualmente (sin read_html)
data = []

for table in tables:
    rows = table.find_all("tr")
    
    for row in rows:
        cols = row.find_all(["td", "th"])
        cols = [c.text.strip() for c in cols]
        
        if len(cols) > 0:
            data.append(cols)

# Convertir a DataFrame
wiki_df = pd.DataFrame(data)

# Guardar CSV
wiki_df.to_csv("../data/wiki_launches.csv", index=False)

print("CSV guardado correctamente")
print(wiki_df.head())
# Out:
# Status code: 200
# Tablas encontradas: 5
# CSV guardado correctamente
#                                                    0  \
# 0                                         Flight No.
# 1                                                286
# 2  Launch of 22 Starlink v2 mini satellites, incl...
# 3                                                287
# 4  Broadband internet provider satellite.[25] Fir...
#
#                           1                   2                       3  \
# 0        Date andtime (UTC)  Version,booster[j]              Launchsite
# 1  January 3, 202403:44[23]        F9 B5B1082‑1      Vandenberg, SLC‑4E
# 2                       NaN                 NaN                     NaN
# 3  January 3, 202423:04[24]       F9 B5B1076‑10  Cape Canaveral, SLC‑40
# 4                       NaN                 NaN                     NaN
#
#                                      4                       5      6  \
# 0                           Payload[k]            Payload mass  Orbit
# 1  Starlink: Group 7-9 (22 satellites)  ~16,800 kg (37,000 lb)    LEO
# 2                                  NaN                     NaN    NaN
# 3                              Ovzon-3     1,800 kg (4,000 lb)    GTO
# 4                                  NaN                     NaN    NaN
#
#           7              8                 9
# 0  Customer  Launchoutcome    Boosterlanding
# 1    SpaceX        Success  Success (OCISLY)
# 2       NaN            NaN               NaN
# 3     Ovzon        Success    Success (LZ‑1)
# 4       NaN            NaN               NaN
