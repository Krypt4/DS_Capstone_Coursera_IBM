# %%
import pandas as pd

df = pd.read_csv("../data/dataset_part_2.csv")

success_df = df[df["Class"] == 1]

success_df = success_df.sort_values("Date")

first_date = success_df["Date"].iloc[0]

print("First successful landing on ground pad:", first_date)
# Out:
# First successful landing on ground pad: 2010-06-04T18:45:00.000Z
