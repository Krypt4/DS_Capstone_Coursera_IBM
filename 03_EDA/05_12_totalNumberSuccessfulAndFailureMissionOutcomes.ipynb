# %%
import pandas as pd

df = pd.read_csv("../data/dataset_part_2.csv")

outcome_counts = df["Class"].value_counts()

print("Failure (0):", outcome_counts.get(0, 0))
print("Success (1):", outcome_counts.get(1, 0))
# Out:
# Failure (0): 19
# Success (1): 176
