# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("../data/dataset_part_2.csv")

sns.catplot(
    data=df,
    x="FlightNumber",
    y="LaunchSite",
    hue="Class"
)

plt.show()
