# %%
import pandas as pd

df = pd.read_csv("../data/dataset_part_2.csv")

df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

df_2015 = df[df["Date"].dt.year == 2015]

failed_drone = df_2015[df_2015["Class"] == 0]

result = failed_drone[["BoosterVersion", "LaunchSite", "Outcome"]]

print(result)
# Out:
#    BoosterVersion    LaunchSite Outcome
# 18       Falcon 9  CCSFS SLC 40   False
