# %%
import pandas as pd

df = pd.read_csv("../data/dataset_part_2.csv")

success_df = df[df["Class"] == 1]

payload_df = success_df[
    (success_df["PayloadMass"] > 4000) &
    (success_df["PayloadMass"] < 6000)
]

drone_df = payload_df 

boosters = drone_df["BoosterVersion"].unique()

print(boosters)
# Out:
# <StringArray>
# ['Falcon 9']
# Length: 1, dtype: str
