# %%
import pandas as pd

df = pd.read_csv("../data/dataset_part_2.csv")

ccsfs_records = df[df["LaunchSite"].str.contains("CCSFS", na=False)].head(5)

print(ccsfs_records)
# Out:
#    FlightNumber                      Date BoosterVersion  PayloadMass Orbit  \
# 0             6  2010-06-04T18:45:00.000Z       Falcon 9          0.0   LEO
# 1             7  2010-12-08T15:43:00.000Z       Falcon 9          0.0   LEO
# 2             8  2012-05-22T07:44:00.000Z       Falcon 9        525.0   LEO
# 3             9  2012-10-08T00:35:00.000Z       Falcon 9        800.0   ISS
# 4            10  2013-03-01T19:10:00.000Z       Falcon 9        677.0   ISS
#
#      LaunchSite Outcome  Class
# 0  CCSFS SLC 40    True      1
# 1  CCSFS SLC 40    True      1
# 2  CCSFS SLC 40    True      1
# 3  CCSFS SLC 40    True      1
# 4  CCSFS SLC 40    True      1
